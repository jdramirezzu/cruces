# %%
# importar bibliotecas necesarias

import pandas as pd
import numpy as np
from datetime import date
import sqlalchemy as sql

# %%
engine = sql.create_engine("mysql://mysql:reportserver@34.74.68.92:3306/BIServer")

# %%
fecha_inicio = input("Por favor inserte la fecha en formato aaaa-mm-dd")
# Out:
# Por favor inserte la fecha en formato aaaa-mm-dd2021-01-15

# %%
fecha_fin = input("Por favor inserte la fecha en formato aaaa-mm-dd")
# Out:
# Por favor inserte la fecha en formato aaaa-mm-dd2021-01-20

# %%
sql_data = pd.read_sql_query(f"SELECT Agencia_movimiento, Cliente, Cedula, Producto, Nro_Cuenta, Canal, Fecha_Movimiento, Monto_Movimiento, Saldo_Final FROM vw_rs_depositos_movimiento WHERE (Producto = 'APORTES ORDINARIOS' OR Producto = 'PLAN APORTES MENSUAL') AND (Fecha_Movimiento BETWEEN '{fecha_inicio}' AND '{fecha_fin}') AND (Canal <> 'Capitalización Aportes' AND Monto_Movimiento > 80000)",engine)

# %%
sql_data
# Out:
#     Agencia_Movimiento                           Cliente      Cedula  \
# 0                TULUA         MARIA BLANCA  LOPEZ SANTA    29757187
# 1                 BUGA            JOHN JAIRO OBANDO LAME    94419562
# 2              ARMENIA      HUGO HUMBERTO MUNEVAR IBAGON    17192744
# 3              ARMENIA      HUGO HUMBERTO MUNEVAR IBAGON    17192744
# 4              ARMENIA                MARIANA GIL MEDINA  1091886885
# ..                 ...                               ...         ...
# 106         FUNDADORES          KAREN SOFIA PENCUA LOPEZ  1094905486
# 107           QUIMBAYA        JAHN MILIANA GARCES MEDINA    29815056
# 108           QUIMBAYA  RIGOBERTO DE JESUS GARCIA PAREJA     6465466
# 109           QUIMBAYA          LUZ ALEYDA PINEDA FLOREZ    24808877
# 110            TEBAIDA     LUIS FERNANDO JIMENEZ QUITIAN  1101020179
#
#                  Producto         Nro_Cuenta               Canal  \
# 0      APORTES ORDINARIOS  04400000000021629                Caja
# ...

# %%
cartera = pd.read_sql_query(f"SELECT Fecha_Desembolso, Identificación_Asociado FROM vw_rs_cartera_x_edades WHERE Fecha_Desembolso BETWEEN '{fecha_inicio}' AND '{fecha_fin}'",engine)

# %%
cartera
# Out:
#     Fecha_Desembolso Identificación_Asociado
# 0         2021-01-15                80226688
# 1         2021-01-15                29757187
# 2         2021-01-15              1094898784
# 3         2021-01-15                 4551469
# 4         2021-01-15                93062029
# ..               ...                     ...
# 133       2021-01-20                14880454
# 134       2021-01-20              1101020179
# 135       2021-01-20                24808877
# 136       2021-01-20              1094963126
# 137       2021-01-20                16365642
#
# [138 rows x 2 columns]

# %%
cruce_1 = sql_data.merge(cartera,how ='left',left_on='Cedula', right_on='Identificación_Asociado')

# %%
cruce_1
# Out:
#     Agencia_Movimiento                           Cliente      Cedula  \
# 0                TULUA         MARIA BLANCA  LOPEZ SANTA    29757187
# 1                 BUGA            JOHN JAIRO OBANDO LAME    94419562
# 2              ARMENIA      HUGO HUMBERTO MUNEVAR IBAGON    17192744
# 3              ARMENIA      HUGO HUMBERTO MUNEVAR IBAGON    17192744
# 4              ARMENIA                MARIANA GIL MEDINA  1091886885
# ..                 ...                               ...         ...
# 109         FUNDADORES          KAREN SOFIA PENCUA LOPEZ  1094905486
# 110           QUIMBAYA        JAHN MILIANA GARCES MEDINA    29815056
# 111           QUIMBAYA  RIGOBERTO DE JESUS GARCIA PAREJA     6465466
# 112           QUIMBAYA          LUZ ALEYDA PINEDA FLOREZ    24808877
# 113            TEBAIDA     LUIS FERNANDO JIMENEZ QUITIAN  1101020179
#
#                  Producto         Nro_Cuenta               Canal  \
# 0      APORTES ORDINARIOS  04400000000021629                Caja
# ...

# %%
for i in cruce_1.index:
    if pd.isna(cruce_1.loc[i,'Fecha_Desembolso']):
        Monto = cruce_1.loc[i, 'Monto_Movimiento']
        Client = cruce_1.loc[i, 'Cliente']
        Cc = cruce_1.loc[i, 'Cedula']
        Fecha = cruce_1.loc[i, 'Fecha_Movimiento']
        Canal = cruce_1.loc[i, 'Canal']
        cruce_1.loc[i, 'Redmine'] = ('Favor reportar consignacion a aportes de {0} - {1} por {2} realizada el {3} por {4}'.format(Cc, Client, Monto, Fecha, Canal))
    else: 
        cruce_1.drop(cruce_1.loc[i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-e27cd82c397e> in <module>
#       8         cruce_1.loc[i, 'Redmine'] = ('Favor reportar consignacion a aportes de {0} - {1} por {2} realizada el {3} por {4}'.format(Cc, Client, Monto, Fecha, Canal))
#       9     else:
# ---> 10         cruce_1.drop(cruce_1.loc[i, 'Redmine'])
#      11
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# ...

# %%
cruce_1
# Out:
#     Agencia_Movimiento                           Cliente      Cedula  \
# 0                TULUA         MARIA BLANCA  LOPEZ SANTA    29757187
# 1                 BUGA            JOHN JAIRO OBANDO LAME    94419562
# 2              ARMENIA      HUGO HUMBERTO MUNEVAR IBAGON    17192744
# 3              ARMENIA      HUGO HUMBERTO MUNEVAR IBAGON    17192744
# 4              ARMENIA                MARIANA GIL MEDINA  1091886885
# ..                 ...                               ...         ...
# 109         FUNDADORES          KAREN SOFIA PENCUA LOPEZ  1094905486
# 110           QUIMBAYA        JAHN MILIANA GARCES MEDINA    29815056
# 111           QUIMBAYA  RIGOBERTO DE JESUS GARCIA PAREJA     6465466
# 112           QUIMBAYA          LUZ ALEYDA PINEDA FLOREZ    24808877
# 113            TEBAIDA     LUIS FERNANDO JIMENEZ QUITIAN  1101020179
#
#                  Producto         Nro_Cuenta               Canal  \
# 0      APORTES ORDINARIOS  04400000000021629                Caja
# ...
